# %% [markdown]
# ## Preprocessing and Exploratory Data Analysis

# %%
import pandas as pd
import numpy as np
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt
import os
from IPython.display import display
from yellowbrick.features import Rank1D
from yellowbrick.features import Rank2D
from sklearn.feature_selection import mutual_info_regression

# %% [markdown]
# ### Data Information

# %%
# Load the dataset
dataset_path = 'data/data.csv'
data = pd.read_csv(dataset_path)
target_col = 'logS'

# %%
# File and parameters loading
problem_type = 'regression'
data_size = 'small'

# %%
print('Number of instances = %d' % (data.shape[0]))
print('Number of attributes = %d' % (data.shape[1]))
data.head()
# Out:
# Number of instances = 1144
# Number of attributes = 5
#    MolLogP    MolWt  NumRotatableBonds  AromaticProportion  logS
# 0   2.5954  167.850                0.0                 0.0 -2.18
# 1   2.3765  133.405                0.0                 0.0 -2.00
# 2   2.5938  167.850                1.0                 0.0 -1.74
# 3   2.0289  133.405                1.0                 0.0 -1.48
# 4   2.9189  187.375                1.0                 0.0 -3.04

# %% [markdown]
# ##### Data Types

# %%
# Print data types of DataFrame
data.dtypes
# Out:
# MolLogP               float64
# MolWt                 float64
# NumRotatableBonds     float64
# AromaticProportion    float64
# logS                  float64
# dtype: object

# %%
def plot_dataframe_datatypes_small_circle(df):
    datatype_counts = df.dtypes.value_counts()
    plt.figure(figsize=(3, 3))
    plt.pie(datatype_counts, labels=datatype_counts.index.astype(str), autopct='%1.1f%%', startangle=140)
    plt.axis('equal')
    plt.title('Data Type Distribution')
    plt.show()

# %%
plot_dataframe_datatypes_small_circle(data)

# %% [markdown]
# ##### Dataframe Statistics

# %%
# Print description of DataFrame
data.describe().T
# Out:
#                      count        mean         std      min        25%  \
# MolLogP             1144.0    2.449133    1.866003  -7.5714    1.41490
# MolWt               1144.0  204.631675  102.620500  16.0430  122.12600
# NumRotatableBonds   1144.0    2.173951    2.627398   0.0000    0.00000
# AromaticProportion  1144.0    0.364932    0.343305   0.0000    0.00000
# logS                1144.0   -3.057997    2.096502 -11.6000   -4.33225
#
#                          50%         75%       max
# MolLogP               2.3403    3.406475   10.3886
# MolWt               183.5945  270.715750  780.9490
# NumRotatableBonds     1.0000    3.000000   23.0000
# AromaticProportion    0.3750    0.666667    1.0000
# logS                 -2.8705   -1.600000    1.5800

# %% [markdown]
# ##### Which columns could be categorical ?

# %%
# Calculating the number of unique values for each column
unique_values = data.apply(lambda x: x.nunique())

# Creating the histogram
plt.figure(figsize=(6, 4))
unique_values.plot(kind='bar')
plt.title('Number of different values')
plt.ylabel('Unique Values Count')
plt.show()

# %% [markdown]
# ### Dataset Cleaning

# %% [markdown]
# #### Missing Values

# %%
# Print number of missing values
data.isna().sum()
# Out:
# MolLogP               0
# MolWt                 0
# NumRotatableBonds     0
# AromaticProportion    0
# logS                  0
# dtype: int64

# %% [markdown]
# This suggests that there are no missing values in the data.

# %% [markdown]
# #### Duplicate Data

# %%
print('Number of duplicate rows = %d' % (data.duplicated().sum()))
# Find the duplicates
duplicates = data[data.duplicated()]
duplicates
# Out:
# Number of duplicate rows = 15
#       MolLogP    MolWt  NumRotatableBonds  AromaticProportion   logS
# 179   1.69844  107.156                0.0            0.750000  0.380
# 192   3.60230  207.070                0.0            0.909091 -4.400
# 310   2.04560  128.558                0.0            0.750000 -0.700
# 345   2.93590  142.242                6.0            0.000000 -2.580
# 568   3.87820  393.854                8.0            0.260870 -6.340
# 649   2.05760  286.349                4.0            0.315789 -3.420
# 896   1.40080  124.139                1.0            0.666667 -1.960
# 911   5.92900  320.046                3.0            0.666667 -7.200
# 912   6.18790  318.030                2.0            0.666667 -6.900
# 916   2.51800  184.242                1.0            0.857143 -2.700
# 946   0.70040  232.239                2.0            0.352941 -2.322
# 1015  0.47660   80.090                0.0            1.000000  1.100
# 1071  0.76140   70.091                1.0            0.000000  0.320
# 1109  1.97250   70.135                1.0            0.000000 -2.540
# 1120  0.82100  380.662                2.0            0.300000 -2.680

# %%
print('Number of rows before discarding duplicates = %d' % (data.shape[0]))
data = data.drop_duplicates()
print('Number of rows after discarding duplicates = %d' % (data.shape[0]))
# Out:
# Number of rows before discarding duplicates = 1144
# Number of rows after discarding duplicates = 1129

# %% [markdown]
# #### Outliers

# %%
# Boxplot for 'MolLogP'
fig = plt.figure()
plt.boxplot(data['MolLogP'])
plt.xlabel('MolLogP')  # Add x-axis label
plt.ylabel('Values')   # Add y-axis label
plt.title('Boxplot for MolLogP')  # Add a title
plt.show()

# Boxplot for 'MolWt'
fig = plt.figure()
plt.boxplot(data['MolWt'])
plt.xlabel('MolWt')    # Add x-axis label
plt.ylabel('Values')   # Add y-axis label
plt.title('Boxplot for MolWt')   # Add a title
plt.show()

# Boxplot for 'NumRotatableBonds'
fig = plt.figure()
plt.boxplot(data['NumRotatableBonds'])
plt.xlabel('NumRotatableBonds')  # Add x-axis label
plt.ylabel('Values')   # Add y-axis label
plt.title('Boxplot for NumRotatableBonds')  # Add a title
plt.show()

# Boxplot for 'AromaticProportion'
fig = plt.figure()
plt.boxplot(data['AromaticProportion'])
plt.xlabel('AromaticProportion')  # Add x-axis label
plt.ylabel('Values')   # Add y-axis label
plt.title('Boxplot for AromaticProportion')  # Add a title
plt.show()

# Boxplot for 'logS'
fig = plt.figure()
plt.boxplot(data['logS'])
plt.xlabel('logS')      # Add x-axis label
plt.ylabel('Values')   # Add y-axis label
plt.title('Boxplot for logS')   # Add a title
plt.show()

# %% [markdown]
# The boxplots suggest that:
# - the column (MolLogP) contains abnormally high and low values.
# - the 2 columns (MolWt, NumRotatableBonds) contain abnormally high values.
# - the column (logS) contains abnormally low values.
#
# To discard the outliers, we can compute the Z-score for each attribute and remove those instances containing attributes with abnormally high or low Z-score (e.g., if Z > 3 or Z <= -3).

# %%
Z = (data-data.mean())/data.std()
Z[20:25]
# Out:
#      MolLogP     MolWt  NumRotatableBonds  AromaticProportion      logS
# 20  0.408319  0.304805          -0.826556            1.127563 -0.209747
# 21 -0.360149 -0.163766          -0.446596           -1.058433  0.660765
# 22  0.291501 -0.562252          -0.826556            1.127563  0.005489
# 23 -0.527291 -1.030823          -0.446596           -1.058433  0.957314
# 24 -0.319301 -0.894018          -0.446596           -1.058433  0.699030

# %%
def discard_outliers(Z, lower_threshold=-3, upper_threshold=3):
    """
    Discard outliers from a dataframe based on Z-scores.

    Parameters
    ----------
    Z: Pandas dataframe
        The dataframe containing the data.
    lower_threshold: float, optional
        The lower Z-score threshold (default is -3).
    upper_threshold: float, optional
        The upper Z-score threshold (default is 3).

    Returns
    -------
    Z2: Pandas dataframe
        The dataframe after discarding outliers.
    """
    num_rows_before = Z.shape[0]

    # Apply filtering conditions
    Z2 = Z.loc[(((Z > lower_threshold) & (Z <= upper_threshold)).all(axis=1))]
    
    num_rows_after = Z2.shape[0]
    print('Number of rows before discarding outliers = %d' % num_rows_before)
    print('Number of rows after discarding outliers = %d' % num_rows_after)

    return Z2

# %%
data = discard_outliers(Z)
# Out:
# Number of rows before discarding outliers = 1129
# Number of rows after discarding outliers = 1096

# %% [markdown]
# ### Plottings

# %% [markdown]
# #### Ranking

# %% [markdown]
# ##### Ranking 1D

# %%
def rank1d_visualization(dataframe, algorithm='shapiro'):
    # Create a Rank1D visualizer
    visualizer = Rank1D(algorithm=algorithm)

    # Fit the visualizer to the data
    visualizer.fit(dataframe)

    # Transform the data and draw the visualization
    visualizer.transform(dataframe)
    visualizer.show()

# Usage Example
rank1d_visualization(data)

# %% [markdown]
# ##### Ranking 2D according to Pearson

# %%
visualizer = Rank2D(algorithm='pearson')

# Fit the data to the visualizer
visualizer.fit(data) 

# Transform the data and draw/show the plot
visualizer.transform(data)
visualizer.show()
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# <Axes: title={'center': 'Pearson Ranking of 5 Features'}>

# %% [markdown]
# ##### Ranking 2D based on covariance

# %%
visualizer = Rank2D(algorithm='kendalltau')

# Fit the data to the visualizer
visualizer.fit(data) 

# Transform the data and draw/show the plot
visualizer.transform(data)
visualizer.show()
# Out:
# <Axes: title={'center': 'Kendalltau Ranking of 5 Features'}>

# %% [markdown]
# ### Correlation

# %%
corr = data.corr() 
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_72b65_row0_col0, #T_72b65_row1_col1, #T_72b65_row2_col2, #T_72b65_row3_col3, #T_72b65_row4_col4 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_72b65_row0_col1 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_72b65_row0_col2 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_72b65_row0_col3 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_72b65_row0_col4, #T_72b65_row2_col3, #T_72b65_row3_col2, #T_72b65_row4_col0, #T_72b65_row4_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_72b65_row1_col0 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_72b65_row1_col2 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_72b65_row1_col3, #T_72b65_row3_col4 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_72b65_row1_col4 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_72b65_row2_col0 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_72b65_row2_col1 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_72b65_row2_col4 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_72b65_row3_col0 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_72b65_row3_col1 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_72b65_row4_col2 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_72b65_row4_col3 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_72b65">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_72b65_level0_col0" class="col_heading level0 col0" >MolLogP</th>
#       <th id="T_72b65_level0_col1" class="col_heading level0 col1" >MolWt</th>
#       <th id="T_72b65_level0_col2" class="col_heading level0 col2" >NumRotatableBonds</th>
#       <th id="T_72b65_level0_col3" class="col_heading level0 col3" >AromaticProportion</th>
#       <th id="T_72b65_level0_col4" class="col_heading level0 col4" >logS</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_72b65_level0_row0" class="row_heading level0 row0" >MolLogP</th>
#       <td id="T_72b65_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_72b65_row0_col1" class="data row0 col1" >0.468097</td>
#       <td id="T_72b65_row0_col2" class="data row0 col2" >0.205607</td>
#       <td id="T_72b65_row0_col3" class="data row0 col3" >0.250977</td>
#       <td id="T_72b65_row0_col4" class="data row0 col4" >-0.827959</td>
#     </tr>
#     <tr>
#       <th id="T_72b65_level0_row1" class="row_heading level0 row1" >MolWt</th>
#       <td id="T_72b65_row1_col0" class="data row1 col0" >0.468097</td>
#       <td id="T_72b65_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_72b65_row1_col2" class="data row1 col2" >0.394219</td>
#       <td id="T_72b65_row1_col3" class="data row1 col3" >0.098855</td>
#       <td id="T_72b65_row1_col4" class="data row1 col4" >-0.637324</td>
#     </tr>
#     <tr>
#       <th id="T_72b65_level0_row2" class="row_heading level0 row2" >NumRotatableBonds</th>
#       <td id="T_72b65_row2_col0" class="data row2 col0" >0.205607</td>
#       <td id="T_72b65_row2_col1" class="data row2 col1" >0.394219</td>
#       <td id="T_72b65_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_72b65_row2_col3" class="data row2 col3" >-0.296737</td>
#       <td id="T_72b65_row2_col4" class="data row2 col4" >-0.238508</td>
#     </tr>
#     <tr>
#       <th id="T_72b65_level0_row3" class="row_heading level0 row3" >AromaticProportion</th>
#       <td id="T_72b65_row3_col0" class="data row3 col0" >0.250977</td>
#       <td id="T_72b65_row3_col1" class="data row3 col1" >0.098855</td>
#       <td id="T_72b65_row3_col2" class="data row3 col2" >-0.296737</td>
#       <td id="T_72b65_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_72b65_row3_col4" class="data row3 col4" >-0.268108</td>
#     </tr>
#     <tr>
#       <th id="T_72b65_level0_row4" class="row_heading level0 row4" >logS</th>
#       <td id="T_72b65_row4_col0" class="data row4 col0" >-0.827959</td>
#       <td id="T_72b65_row4_col1" class="data row4 col1" >-0.637324</td>
#       <td id="T_72b65_row4_col2" class="data row4 col2" >-0.238508</td>
#       <td id="T_72b65_row4_col3" class="data row4 col3" >-0.268108</td>
#       <td id="T_72b65_row4_col4" class="data row4 col4" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Initialize drop_cols as an empty list if it has not been defined yet
drop_cols = []

# Define your correlation threshold
threshold_corr = 0.75 

# Calculate correlated features
correlated_features = correlated_columns(data, threshold_corr, target_col)

# Concatenate drop_cols and correlated_features and find the unique columns to drop
dropped_cols = np.unique(np.concatenate((drop_cols, correlated_features)))

# Now, dropped_cols will contain all the columns you want to drop

# %% [markdown]
# ##### Splitting dataframe in features and targets

# %%
y = data[target_col]

# %%
X = data.drop(target_col, axis=1)

# %% [markdown]
# ###### Correlation with Yellow Bricks

# %%
features = data.drop(target_col, axis=1)  # drop the target column to isolate features
target = data[target_col]  # isolate the target variable

# Calculate the correlation of each feature with the target
correlations = features.corrwith(target).sort_values()

# Create a horizontal bar chart to display the correlation coefficients
plt.figure(figsize=(10, 6))
sns.barplot(x=correlations, y=correlations.index)
plt.title('Features correlation with dependent variable')
plt.xlabel('Pearson Correlation')
plt.show()
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
